# %%
import numpy as np
import csv
from numpy import *
import os


def get_tf_list(tf_path):
    # return tf_list
    f_tf = open(tf_path)
    tf_reader = list(csv.reader(f_tf))
    tf_list = []
    for single in tf_reader[1:]:
        tf_list.append(single[0])
    print('Load ' + str(len(tf_list)) + ' TFs successfully!')
    return tf_list

def get_origin_expression_data(gene_expression_path):
    # return 1.tf-targets dict and pair-score dict
    #        2.number of timepoints
    f_expression = open(gene_expression_path, encoding="utf-8")
    expression_reader = list(csv.reader(f_expression))
    cells = expression_reader[0][1:]
    num_cells = len(cells)

    expression_record = {}
    num_genes = 0
    for single_expression_reader in expression_reader[1:]:
        if single_expression_reader[0] in expression_record:
            print('Gene name ' + single_expression_reader[0] + ' repeat!')
        expression_record[single_expression_reader[0]] = list(map(float, single_expression_reader[1:]))
        num_genes += 1
    print(str(num_genes) + ' genes and ' + str(num_cells) + ' cells are included in origin expression data.')
    return expression_record, cells

def get_normalized_expression_data(gene_expression_path):
    # return 1.tf-targets dict and pair-score dict
    #        2.number of timepoints
    expression_record, cells = get_origin_expression_data(gene_expression_path)
    expression_matrix = np.zeros((len(expression_record), len(cells)))
    index_row = 0
    for gene in expression_record:
        expression_record[gene] = np.log10(np.array(expression_record[gene]) + 10 ** -2)
        expression_matrix[index_row] = expression_record[gene]
        index_row += 1

    # Heat map
    # plt.figure(figsize=(15,15))
    # sns.heatmap(expression_matrix[0:100,0:100])
    # plt.show()

    return expression_record, cells

def get_gene_ranking(gene_order_path, low_express_gene_list, gene_num, output_path,
                     flag):  # flag=True:write to output_path
    # 1.delete genes p-value>=0.01
    # 2.delete genes with low expression
    # 3.rank genes in descending order of variance
    # 4.return gene names list of top genes and variance_record of p-value<0.01
    f_order = open(gene_order_path)
    order_reader = list(csv.reader(f_order))
    if flag:
        f_rank = open(output_path, 'w', newline='\n')
        f_rank_writer = csv.writer(f_rank)
    variance_record = {}
    variance_list = []
    significant_gene_list = []
    for single_order_reader in order_reader[1:]:
        # column 0:gene name
        # column 1:p value
        # column 2:variance
        if float(single_order_reader[1]) >= 0.01:
            break
        if single_order_reader[0] in low_express_gene_list:
            continue
        variance = float(single_order_reader[2])
        if variance not in variance_record:  # 1 variance corresponding to 1 gene
            variance_record[variance] = single_order_reader[0]
        else:  # 1 variance corresponding to n genes
            print(str(variance_record[variance]) + ' and ' + single_order_reader[0] + ' variance repeat!')
            variance_record[variance] = [variance_record[variance]]
            variance_record[variance].append(single_order_reader[0])
        variance_list.append(variance)
        tstr = single_order_reader[0]
        single_order_reader[0] = tstr.upper()
        significant_gene_list.append(single_order_reader[0])
    print('After delete genes with p-value>=0.01 or low expression, ' + str(len(variance_list)) + ' genes left.')
    variance_list.sort(reverse=True)
    gene_rank = []
    for single_variance_list in variance_list[0:gene_num]:
        if type(variance_record[single_variance_list]) is str:  # 1 variance corresponding to 1 gene
            gene_rank.append(variance_record[single_variance_list])
        else:  # 1 variance corresponding to n genes
            gene_rank.append(variance_record[single_variance_list][0])
            del variance_record[single_variance_list][0]
            if len(variance_record[single_variance_list]) == 1:
                variance_record[single_variance_list] = variance_record[single_variance_list][0]
        if flag:
            f_rank_writer.writerow([variance_record[single_variance_list]])
    f_order.close()
    if flag:
        f_rank.close()
    return gene_rank, significant_gene_list

def get_filtered_gold(gold_network_path, rank_list, output_path, flag):
    # 1.Load origin gold file
    # 2.Delete genes not in rank_list
    # 3.return tf-targets dict and pair-score dict
    # Note: If no score in gold network, score=999
    f_gold = open(gold_network_path, encoding='UTF-8-sig')
    gold_reader = list(csv.reader(f_gold))
    for i in range(0, len(gold_reader) - 1):
        temp = gold_reader[i]
        s1 = str(temp[0])
        s2 = str(temp[1])

        temp[0] = s1.upper()
        temp[1] = s2.upper()

        gold_reader[i] = temp
    print("gold_reader",gold_reader)
    print("rank_list",rank_list)
    print("gold_reader",gold_reader)
    print("gold_reader[0]", gold_reader[0])
    has_score = True
    if len(gold_reader[0]) < 3:
        has_score = False
    gold_pair_record = {}
    gold_score_record = {}
    unique_gene_list = []
    for single_gold_reader in gold_reader[1:]:
        # column 0: TF
        # column 1: target gene
        # column 2: regulate score
        if (single_gold_reader[0] not in rank_list) or (single_gold_reader[1] not in rank_list):
            continue
        gene_pair = [single_gold_reader[0], single_gold_reader[1]]
        str_gene_pair = single_gold_reader[0] + ',' + single_gold_reader[1]

        if single_gold_reader[0] not in unique_gene_list: unique_gene_list.append(single_gold_reader[0])
        if single_gold_reader[1] not in unique_gene_list: unique_gene_list.append(single_gold_reader[1])
        if str_gene_pair in gold_score_record:
            print('Gold pair repeat!')
        if has_score:
            print("single_gold_reader[2]", single_gold_reader[2])
            gold_score_record[str_gene_pair] = float(single_gold_reader[2])
        else:
            gold_score_record[str_gene_pair] = 999
        if gene_pair[0] not in gold_pair_record:
            gold_pair_record[gene_pair[0]] = [gene_pair[1]]
        else:
            gold_pair_record[gene_pair[0]].append(gene_pair[1])
    print("gold_pair_record", gold_pair_record)
    # Some statistics of gold_network
    print(str(len(gold_pair_record)) + ' TFs and ' + str(
        len(gold_score_record)) + ' edges in gold_network consisted of genes in rank_list.')
    print(str(len(unique_gene_list)) + ' genes are common in rank_list and gold_network.')

    rank_density = len(gold_score_record) / (len(gold_pair_record) * (len(rank_list)))
    gold_density = len(gold_score_record) / (len(gold_pair_record) * (len(unique_gene_list)))

    print('Rank genes density = edges/(TFs*(len(rank_gene)-1))=' + str(rank_density))
    print('Gold genes density = edges/(TFs*len(unique_gene_list))=' + str(gold_density))

    # write to file
    print("unique_gene_list", unique_gene_list)
    if flag:
        f_unique = open(output_path, 'w', encoding="utf-8", newline='\n')
        f_unique_writer = csv.writer(f_unique)
        out_unique = np.array(unique_gene_list).reshape(len(unique_gene_list), 1)
        f_unique_writer.writerows(out_unique)
        f_unique.close()
    return gold_pair_record, gold_score_record, unique_gene_list

def generate_filtered_gold(gold_pair_record, gold_score_record, output_path):
    # write filtered_gold to output_path
    # print("cnm")
    f_filtered = open(output_path, 'w', encoding="utf-8", newline='\n')
    f_filtered_writer = csv.writer(f_filtered)
    f_filtered_writer.writerow(['TF', 'Target', 'Score'])
    # print("cnm")
    for tf in gold_pair_record:
        once_output = []
        for target in gold_pair_record[tf]:
            single_output = [tf, target, gold_score_record[tf + ',' + target]]
            once_output.append(single_output)
        f_filtered_writer.writerows(once_output)
    f_filtered.close()

def get_gene_pair_list(unique_gene_list, gold_pair_record, gold_score_record, output_file):
    # positive is relationship that tf regulate target
    # negtive is reationship that same tf doesn's regulate target.
    # When same tf doesn't have enough negtive, borrow negtive from other TFs.
    # When negtive is not enough,stop and prove positive:negtive = 1:1

    # generate all negtive gene pairs of TFs
    all_tf_negtive_record = {}
    for tf in gold_pair_record:
        # print("tf",tf)
        all_tf_negtive_record[tf] = []
        for target in unique_gene_list:
            if target in gold_pair_record[tf]:
                continue
            all_tf_negtive_record[tf].append(target)

    # generate negtive record without borrow
    rank_negtive_record = {}
    for tf in gold_pair_record:
        num_positive = len(gold_pair_record[tf])
        if num_positive > len(all_tf_negtive_record[tf]):
            rank_negtive_record[tf] = all_tf_negtive_record[tf]
            all_tf_negtive_record[tf] = []
        else:
            # maybe random.sample(all_tf_negtive_record[tf],num_positive) to promote performance
            rank_negtive_record[tf] = all_tf_negtive_record[tf][:num_positive]
            all_tf_negtive_record[tf] = all_tf_negtive_record[tf][num_positive:]

    # output positive and negtive pairs
    f_gpl = open(output_file, 'w', newline='\n')
    f_gpl_writer = csv.writer(f_gpl)
    f_gpl_writer.writerow(['TF', 'Target', 'Label', 'Score'])
    stop_flag = False
    for tf in gold_pair_record:
        once_output = []
        for target in gold_pair_record[tf]:
            # output positive
            single_output = [tf, target, '1', gold_score_record[tf + ',' + target]]
            once_output.append(single_output)
            # output negtive
            if len(rank_negtive_record[tf]) == 0:
                # borrow negtive for other TFs
                find_negtive = False
                for borrow_tf in all_tf_negtive_record:
                    if len(all_tf_negtive_record[borrow_tf]) > 0:
                        find_negtive = True
                        single_output = [borrow_tf, all_tf_negtive_record[borrow_tf][0], 0, 0]
                        del all_tf_negtive_record[borrow_tf][0]
                        break
                # if not enough negtive of others,stop and prove positive:negtive = 1:1
                if not find_negtive:
                    stop_flag = True
                    break
            else:
                # negtive without borrow
                single_output = [tf, rank_negtive_record[tf][0], 0, 0]
                del rank_negtive_record[tf][0]
            once_output.append(single_output)
        if stop_flag:
            f_gpl_writer.writerows(once_output[:-1])
            print('Negtive not enough!')
            break
        f_gpl_writer.writerows(once_output)  # output positive and negtive of 1 TF at a time
    f_gpl.close()

def get_low_express_gene(origin_expression_record, num_cells):
    # get gene_list who were expressed in fewer than 10% of the cells
    gene_list = []
    threshold = num_cells // 10
    for gene in origin_expression_record:
        num = 0
        for expression in origin_expression_record[gene]:
            if expression != 0:
                num += 1
                if num > threshold:
                    break
        if num <= threshold:
            gene_list.append(gene)
    return gene_list


def loadData(network, dataset):

    gene_pair_list_path =  network
    gene_expression_path = dataset
    resultPath = "data/input/"
    origin_expression_record, cells = get_normalized_expression_data(gene_expression_path)
    print("len(origin_expression_record)", len(origin_expression_record))

    # Load gold_pair_record
    all_gene_list = []
    gold_pair_record = {}
    f_genePairList = open(gene_pair_list_path, encoding='UTF-8')  ### read the gene pair and label file

    for single_pair in list(csv.reader(f_genePairList))[1:]:
        print("single_pair",single_pair)
        if single_pair[2] == '1':
            if single_pair[0] not in gold_pair_record:
                gold_pair_record[single_pair[0]] = [single_pair[1]]
            else:
                gold_pair_record[single_pair[0]].append(single_pair[1])
            # count all genes in gold edges
            if single_pair[0] not in all_gene_list:
                all_gene_list.append(single_pair[0])
            if single_pair[1] not in all_gene_list:
                all_gene_list.append(single_pair[1])
    f_genePairList.close()
    # print dataset statistics
    print('All genes:' + str(len(all_gene_list)))
    print('TFs:' + str(len(gold_pair_record.keys())))
    print("len(single_pair)", len(single_pair))
    # Generate Pearson matrix
    label_list = []
    pair_list = []
    total_matrix = []
    num_tf = -1
    num_label1 = 0
    num_label0 = 0
    miss = 0

    # control cell numbers by means of timepoints
    timepoints = len(cells)
    # timepoints=800
    x = []
    for i in gold_pair_record:
        num_tf += 1
        for j in range(len(all_gene_list)):
            # for j in range(2):
            print('Generating matrix of gene pair ' + str(num_tf) + ' ' + str(j))
            tf_name = i
            target_name = all_gene_list[j]

            flag = False
            if (origin_expression_record.__contains__(tf_name) & origin_expression_record.__contains__(target_name)):
                flag = True

            if (flag):
                if tf_name in gold_pair_record and target_name in gold_pair_record[tf_name]:
                    label = 1
                    num_label1 += 1
                else:
                    label = 0
                    num_label0 += 1
                label_list.append(label)
                pair_list.append(tf_name + ',' + target_name)

                tf_data = origin_expression_record[tf_name]
                target_data = origin_expression_record[target_name]
            else:
                miss = miss + 1
                continue

            single_tf_list = []
            gap = 100
            for k in range(0, len(tf_data), gap):
                feature = []
                a = tf_data[k:k + gap]
                b = target_data[k:k + gap]
                feature.extend(a)
                feature.extend(b)
                # single_tf_list.append(feature)
                feature = np.asarray(feature)
                # print("feature.shape", feature.shape)
                if (len(feature) == 2 * gap):
                    # print("feature.shape xixihaha", feature.shape)
                    single_tf_list.append(feature)

            single_tf_list = np.asarray(single_tf_list)

            total_matrix.append(single_tf_list)

    total_matrix = np.asarray(total_matrix)
    label_list = np.array(label_list)
    # print("label_list.shape", label_list.shape)
    pair_list = np.array(pair_list)

    np.save(resultPath + 'matrix.npy', total_matrix)
    np.save(resultPath + 'label.npy', label_list)
    np.save(resultPath + 'gene_pair.npy', pair_list)

    print('PCC matrix generation finish.')
    print('Positive edges:' + str(num_label1))
    print('Negative edges:' + str(num_label0))
    print('Density=' + str(num_label1 / (num_label1 + num_label0)))

# %%
from sklearn.model_selection import train_test_split
import numpy as np
import torch
import torch.nn.functional as F
import torch.nn as nn
import warnings
warnings.filterwarnings('ignore')
from sklearn import metrics
import os
import csv
import math
from torch.utils.data import (DataLoader)
torch.set_default_tensor_type(torch.DoubleTensor)

def numpy2loader(X, y, batch_size):
    X_set = torch.from_numpy(X)
    X_loader = DataLoader(X_set, batch_size=batch_size)
    y_set = torch.from_numpy(y)
    y_loader = DataLoader(y_set, batch_size=batch_size)

    return X_loader, y_loader

def loaderToList(data_loader):
    length = len(data_loader)
    data = []
    for i in data_loader:
        data.append(i)
    return data

class PositionalEncoding(nn.Module):

    def __init__(self, d_model, dropout=0.1, max_len=5000):
        super(PositionalEncoding, self).__init__()
        self.dropout = nn.Dropout(p=dropout)

        pe = torch.zeros(max_len, d_model)
        position = torch.arange(0, max_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return self.dropout(x)

class STGRNS(nn.Module):
    def __init__(self, input_dim, nhead=2, d_model=80, num_classes=2, dropout=0.1):
        super().__init__()
        self.prenet = nn.Linear(input_dim, d_model)
        self.positionalEncoding = PositionalEncoding(d_model=d_model, dropout=dropout)
        self.encoder_layer = nn.TransformerEncoderLayer(
            d_model=d_model, dim_feedforward=256, nhead=2, dropout=dropout
        )

        self.pred_layer = nn.Sequential(
            nn.Linear(d_model, d_model),
            nn.ReLU(),
            nn.Linear(d_model, num_classes),
        )

    def forward(self, window_size):
        out = window_size.permute(1, 0, 2)
        out = self.positionalEncoding(out)
        out = self.encoder_layer(out)
        out = out.transpose(0, 1)
        stats = out.mean(dim=1)
        out = self.pred_layer(stats)
        return out



import numpy as np
import torch
import torch.nn.functional as F
from sklearn import metrics

def STGRNSForGRNSRconstruction(batch_sizes, epochs, known_data_path, unknown_data_path, num_threads):
    data_path = known_data_path
    d_models = 200
    torch.set_num_threads(num_threads)  # set num_threads
    batch_size = batch_sizes
    log_dir = "log/"
    if not os.path.isdir(log_dir):
        os.makedirs(log_dir)

    # Load training data
    x_train = np.load(data_path + 'matrix.npy')
    y_train = np.load(data_path + 'label.npy')

    X_trainloader, y_trainloader = numpy2loader(x_train, y_train, batch_size)
    X_trainList = loaderToList(X_trainloader)
    y_trainList = loaderToList(y_trainloader)

    # Model setup
    model = STGRNS(input_dim=200, nhead=2, d_model=d_models, num_classes=2)
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.0003, weight_decay=1e-5)

    # Training loop
    for epoch in range(epochs):
        train_losses = []
        model.train()
        for data, labels in zip(X_trainList, y_trainList):
            logits = model(data)
            labels = torch.tensor(labels, dtype=torch.long)
            loss = criterion(logits, labels)
            optimizer.zero_grad()
            loss.backward()
            nn.utils.clip_grad_norm_(model.parameters(), max_norm=10)
            optimizer.step()
            train_losses.append(loss.item())

        print(f"[Train | {epoch+1:03d}/{epochs:03d}] Loss = {np.mean(train_losses):.5f}")

    # Prediction
    data_path = unknown_data_path
    x_test = np.load(data_path + 'matrix.npy')
    y_test = np.load(data_path + 'label.npy')

    X_testloader, y_testloader = numpy2loader(x_test, y_test, batch_size)
    X_testList = loaderToList(X_testloader)

    model.eval()
    y_scores = []
    with torch.no_grad():
        for data in X_testList:
            logits = model(data)
            probs = F.softmax(logits, dim=1)[:, 1]
            y_scores.extend(probs.cpu().numpy())

    y_scores = np.array(y_scores)
    y_true = np.array(y_test)

    # Compute ROC AUC
    fpr, tpr, _ = metrics.roc_curve(y_true, y_scores, pos_label=1)
    roc_auc = metrics.auc(fpr, tpr)

    # Compute Precision-Recall AUC
    precision, recall, _ = metrics.precision_recall_curve(y_true, y_scores)
    pr_auc = metrics.auc(recall, precision)

    # Baseline (random) AUPR
    pos_rate = np.mean(y_true)
    pr_auc_ratio = pr_auc / pos_rate

    # Early Precision (Precision at Recall >= 0.1)
    recall_target = 0.1
    idx = np.argmax(recall >= recall_target)
    early_precision = precision[idx]
    early_precision_ratio = early_precision / pos_rate

    # Binarize at threshold for classification metrics
    threshold = 0.5
    y_pred = (y_scores >= threshold).astype(int)
    acc = metrics.accuracy_score(y_true, y_pred)
    bacc = metrics.balanced_accuracy_score(y_true, y_pred)
    f1 = metrics.f1_score(y_true, y_pred)

    # Print metrics
    print(f"ROC AUC: {roc_auc:.4f}")
    print(f"PR AUC: {pr_auc:.4f}")
    print(f"AUPR Ratio (AUPR / pos_rate): {pr_auc_ratio:.4f}")
    print(f"Early Precision @ Recall={recall_target}: {early_precision:.4f}")
    print(f"Early Precision Ratio: {early_precision_ratio:.4f}")
    print(f"Accuracy: {acc:.4f}, Balanced Acc: {bacc:.4f}, F1 Score: {f1:.4f}")

    # Save predictions
    np.save(os.path.join(log_dir, 'y_test.npy'), y_true)
    np.save(os.path.join(log_dir, 'y_scores.npy'), y_scores)
    np.save(os.path.join(log_dir, 'y_pred.npy'), y_pred)

    return {
        'roc_auc': roc_auc,
        'pr_auc': pr_auc,
        'pr_auc_ratio': pr_auc_ratio,
        'early_precision': early_precision,
        'early_precision_ratio': early_precision_ratio,
        'accuracy': acc,
        'balanced_accuracy': bacc,
        'f1_score': f1
    }

# %%
known_network = "data/known_network.csv"

unknown_network = "data/unknown_network.csv"
dataset = "data/06hHep_ExpressionDataOrdered.csv"

##generating the data can be inputted by the STGRNS

# only run one at a time
loadData(known_network, dataset) #known
loadData(unknown_network, dataset) # unknow
# Out:
# Gene name 1-Mar repeat!
# 8389 genes and 425 cells are included in origin expression data.
# len(origin_expression_record) 8388
# single_pair ['ID3', 'MCM4', '0']
# single_pair ['CRABP2', 'TNNI3', '0']
# single_pair ['ID3', 'SMYD3', '0']
# single_pair ['FOS', 'DPYSL2', '0']
# single_pair ['KLF6', 'CAPN12', '0']
# single_pair ['CRABP2', 'TGIF1', '0']
# single_pair ['CRABP2', 'FANCB', '0']
# single_pair ['RUVBL1', 'ANXA3', '0']
# single_pair ['TGIF1', 'KIF20B', '0']
# single_pair ['RUVBL1', 'CDK1', '0']
# single_pair ['DDIT3', 'FANCB', '1']
# single_pair ['PITX2', 'NIP7', '0']
# single_pair ['PITX2', 'NIF3L1', '0']
# single_pair ['ZNF143', 'BUB1B', '1']
# single_pair ['DDIT3', 'PLK1', '0']
# single_pair ['TGIF1', 'OTX2', '0']
# single_pair ['FOS', 'NEK2', '1']
# single_pair ['MCM4', 'FANCB', '0']
# single_pair ['PITX2', 'OCIAD2', '0']
# single_pair ['CRABP2', 'PHF5A', '0']
# single_pair ['ID2', 'PTTG1', '0']
# single_pair ['MCM4', 'MCM7', '1']
# single_pair ['MCM3', 'ANXA3', '0']
# single_pair ['ZNF143', 'KIF20B', '0']
# single_pair ['MCM7', 'CCL2', '0']
# single_pair ['KLF6', 'NQO1', '0']
# single_pair ['MCM3', 'NEK2', '0']
# single_pair ['ID3', 'RUVBL1', '0']
# single_pair ['MCM4', 'TPD52L1', '0']
# single_pair ['ID2', 'SMYD3', '0']
# single_pair ['ID2', 'VTN', '0']
# single_pair ['MCM4', 'FOS', '0']
# single_pair ['ID3', 'ANXA3', '0']
# single_pair ['RUVBL1', 'KLF6', '0']
# single_pair ['DDIT3', 'ADM', '1']
# single_pair ['ZNF143', 'ID3', '0']
# single_pair ['MCM7', 'TGIF1', '0']
# single_pair ['ID3', 'NIP7', '0']
# single_pair ['MCM7', 'NFYB', '0']
# single_pair ['PITX2', 'UBE2T', '0']
# single_pair ['PTTG1', 'UBE2T', '0']
# single_pair ['KNTC1', 'ANXA3', '0']
# single_pair ['MCM3', 'NQO1', '0']
# single_pair ['ZNF143', 'MCM3', '0']
# single_pair ['NFYB', 'ACTL6A', '0']
# single_pair ['MCM3', 'CA2', '0']
# single_pair ['MCM4', 'MRPS27', '0']
# single_pair ['TGIF1', 'TGIF1', '1']
# single_pair ['RUVBL1', 'HESX1', '0']
# single_pair ['KLF6', 'MCM7', '0']
# single_pair ['MCM7', 'CDK1', '0']
# single_pair ['ID3', 'NIF3L1', '0']
# single_pair ['PITX2', 'CAMK2D', '0']
# single_pair ['PTTG1', 'IQGAP2', '0']
# single_pair ['MCM4', 'ACTC1', '0']
# single_pair ['MCM3', 'TPD52L1', '0']
# single_pair ['RUVBL1', 'CENPF', '0']
# single_pair ['ID3', 'CRABP2', '0']
# single_pair ['MCM4', 'ID3', '0']
# single_pair ['RUVBL1', 'LGALS3', '0']
# single_pair ['CRABP2', 'CCS', '0']
# single_pair ['TGIF1', 'CENPF', '0']
# single_pair ['ID3', 'MCM7', '0']
# single_pair ['OTX2', 'SERPINB1', '0']
# single_pair ['ID2', 'IQGAP2', '0']
# single_pair ['MCM3', 'CHEK2', '0']
# single_pair ['MCM4', 'PMAIP1', '0']
# single_pair ['KNTC1', 'ACADVL', '0']
# single_pair ['MCM7', 'MRPS27', '0']
# single_pair ['FOS', 'CRABP2', '1']
# single_pair ['PTTG1', 'HESX1', '0']
# single_pair ['CRABP2', 'PRKCE', '0']
# single_pair ['TGIF1', 'MCM3', '0']
# single_pair ['PTTG1', 'RBP4', '0']
# single_pair ['PITX2', 'NFYB', '0']
# single_pair ['NFYB', 'OTX2', '0']
# single_pair ['MCM4', 'RBP4', '0']
# single_pair ['DDIT3', 'ANAPC7', '0']
# single_pair ['FOS', 'HESX1', '0']
# single_pair ['KLF6', 'CCNB1', '0']
# single_pair ['MCM3', 'MCM7', '1']
# single_pair ['ZNF143', 'AURKA', '0']
# single_pair ['ZNF143', 'RUVBL1', '0']
# single_pair ['FOS', 'OCIAD2', '1']
# single_pair ['PTTG1', 'PCCA', '0']
# single_pair ['ID3', 'ACTL6A', '0']
# single_pair ['RUVBL1', 'VTN', '0']
# single_pair ['ID3', 'AURKA', '0']
# single_pair ['FOS', 'CENPF', '0']
# single_pair ['PTTG1', 'NFYB', '0']
# single_pair ['ID3', 'NEK2', '0']
# single_pair ['TGIF1', 'OCIAD2', '0']
# single_pair ['MCM3', 'FANCB', '0']
# single_pair ['KNTC1', 'ADM', '0']
# single_pair ['MCM7', 'DDIT3', '0']
# single_pair ['FOS', 'CCNB1', '0']
# single_pair ['RUVBL1', 'ACTC1', '0']
# single_pair ['CRABP2', 'CCNB1', '0']
# single_pair ['TGIF1', 'ACADVL', '0']
# single_pair ['KNTC1', 'GRPR', '0']
# single_pair ['KLF6', 'GPC3', '0']
# single_pair ['ZNF143', 'PCNA', '0']
# single_pair ['ZNF143', 'UBE2T', '0']
# single_pair ['ID2', 'RUVBL1', '0']
# single_pair ['PTTG1', 'MTFP1', '0']
# single_pair ['KNTC1', 'TF', '0']
# single_pair ['PTTG1', 'AURKA', '0']
# single_pair ['MCM4', 'BUB1B', '0']
# single_pair ['PTTG1', 'VTN', '0']
# single_pair ['OTX2', 'MRPS27', '0']
# single_pair ['MCM4', 'NEK2', '0']
# single_pair ['NFYB', 'KIF20B', '0']
# single_pair ['PITX2', 'ACTC1', '0']
# single_pair ['TGIF1', 'UQCC1', '0']
# single_pair ['OTX2', 'PRMT5', '0']
# single_pair ['ZNF143', 'ACADVL', '0']
# single_pair ['RUVBL1', 'SCHIP1', '0']
# single_pair ['MCM3', 'PIM2', '0']
# single_pair ['KLF6', 'ATG5', '0']
# single_pair ['DDIT3', 'NIP7', '1']
# single_pair ['ZNF143', 'VTN', '0']
# single_pair ['MCM3', 'APEH', '0']
# single_pair ['OTX2', 'PLK1', '0']
# single_pair ['MCM3', 'DKC1', '0']
# single_pair ['KNTC1', 'UTRN', '0']
# single_pair ['DDIT3', 'CYP3A5', '0']
# single_pair ['PTTG1', 'ACADVL', '0']
# single_pair ['CRABP2', 'ANAPC7', '0']
# single_pair ['KLF6', 'ID3', '0']
# single_pair ['ZNF143', 'GPC3', '0']
# single_pair ['MCM4', 'ZWILCH', '0']
# single_pair ['CRABP2', 'PTTG1', '0']
# single_pair ['TGIF1', 'RBP4', '0']
# single_pair ['KNTC1', 'PHF5A', '0']
# single_pair ['ID2', 'PCCA', '0']
# single_pair ['MCM7', 'GPC3', '0']
# single_pair ['MCM4', 'F3', '0']
# single_pair ['NFYB', 'UQCC1', '0']
# single_pair ['ID2', 'PMAIP1', '0']
# single_pair ['NFYB', 'PRMT5', '0']
# single_pair ['MCM4', 'UQCC1', '0']
# single_pair ['RUVBL1', 'LGALS1', '0']
# single_pair ['NFYB', 'CCL2', '0']
# single_pair ['ID2', 'ANXA3', '0']
# single_pair ['FOS', 'HAUS1', '0']
# single_pair ['ID3', 'CDC20', '0']
# single_pair ['OTX2', 'ACTL6A', '0']
# single_pair ['MCM7', 'CYP3A5', '0']
# single_pair ['NFYB', 'PCNA', '1']
# single_pair ['NFYB', 'DDIT3', '1']
# single_pair ['ID2', 'ATG5', '0']
# single_pair ['OTX2', 'NIP7', '0']
# single_pair ['MCM7', 'SMYD3', '0']
# single_pair ['PTTG1', 'TF', '0']
# single_pair ['CRABP2', 'RUVBL1', '0']
# single_pair ['ID3', 'HESX1', '0']
# single_pair ['OTX2', 'LGALS3', '0']
# single_pair ['ZNF143', 'HESX1', '0']
# single_pair ['PTTG1', 'GRPR', '0']
# single_pair ['KNTC1', 'UQCC1', '0']
# single_pair ['CRABP2', 'ACADVL', '0']
# single_pair ['KLF6', 'ANXA3', '0']
# single_pair ['PITX2', 'CRABP2', '0']
# single_pair ['ZNF143', 'GRPR', '0']
# single_pair ['ZNF143', 'PCCA', '0']
# single_pair ['TGIF1', 'CAPN12', '0']
# single_pair ['ID2', 'CA2', '0']
# single_pair ['PTTG1', 'NEK2', '0']
# single_pair ['RUVBL1', 'TGIF1', '0']
# single_pair ['ZNF143', 'CCBL2', '0']
# single_pair ['MCM4', 'CACYBP', '0']
# single_pair ['ID3', 'KNTC1', '0']
# single_pair ['MCM3', 'RUVBL1', '0']
# single_pair ['MCM7', 'PLK1', '1']
# single_pair ['FOS', 'NIF3L1', '0']
# single_pair ['NFYB', 'CDC20', '0']
# single_pair ['KLF6', 'ZNF143', '0']
# single_pair ['CRABP2', 'ANXA3', '0']
# single_pair ['MCM7', 'SCHIP1', '0']
# single_pair ['PITX2', 'DKC1', '0']
# single_pair ['MCM7', 'KNTC1', '0']
# single_pair ['FOS', 'PCNA', '0']
# single_pair ['OTX2', 'CHEK2', '0']
# single_pair ['FOS', 'CCNH', '0']
# single_pair ['DDIT3', 'ID3', '1']
# single_pair ['FOS', 'ADM', '1']
# single_pair ['NFYB', 'ID3', '0']
# single_pair ['PITX2', 'IQGAP2', '0']
# single_pair ['PITX2', 'MTFP1', '0']
# single_pair ['MCM3', 'WARS', '0']
# single_pair ['OTX2', 'MCM4', '0']
# single_pair ['ZNF143', 'RBP4', '0']
# single_pair ['NFYB', 'TGIF1', '0']
# single_pair ['CRABP2', 'CA2', '0']
# single_pair ['OTX2', 'FOS', '0']
# single_pair ['NFYB', 'MCM7', '0']
# single_pair ['TGIF1', 'PLK1', '0']
# single_pair ['MCM4', 'PHF5A', '0']
# single_pair ['KLF6', 'NIP7', '0']
# single_pair ['KNTC1', 'PRKCE', '0']
# single_pair ['NFYB', 'NEK2', '0']
# single_pair ['PITX2', 'MRPS27', '0']
# single_pair ['ZNF143', 'TM2D2', '0']
# single_pair ['KLF6', 'AURKA', '0']
# single_pair ['MCM4', 'PCCA', '0']
# single_pair ['ID3', 'KLF6', '0']
# single_pair ['ZNF143', 'ACTC1', '0']
# single_pair ['RUVBL1', 'GSN', '0']
# single_pair ['FOS', 'DDIT3', '1']
# single_pair ['ZNF143', 'TNFRSF12A', '0']
# single_pair ['OTX2', 'HESX1', '1']
# single_pair ['TGIF1', 'NFYB', '0']
# single_pair ['CRABP2', 'CAMK2D', '0']
# single_pair ['PITX2', 'CENPF', '0']
# single_pair ['ID2', 'NIP7', '0']
# single_pair ['KNTC1', 'GSN', '0']
# single_pair ['MCM4', 'DPYSL2', '0']
# single_pair ['KNTC1', 'CAPN12', '0']
# single_pair ['MCM4', 'RUVBL1', '0']
# single_pair ['PITX2', 'SMYD3', '0']
# single_pair ['DDIT3', 'CRABP2', '0']
# single_pair ['FOS', 'ACTL6A', '0']
# single_pair ['ID3', 'PCNA', '0']
# single_pair ['TGIF1', 'PIM2', '0']
# single_pair ['ID2', 'EFTUD2', '0']
# single_pair ['MCM3', 'EFTUD2', '0']
# single_pair ['MCM3', 'KNTC1', '0']
# single_pair ['MCM4', 'ANAPC7', '0']
# single_pair ['ID3', 'APEH', '0']
# single_pair ['DDIT3', 'GRPR', '0']
# single_pair ['ID2', 'ZNF143', '0']
# single_pair ['KLF6', 'MRPS27', '0']
# single_pair ['DDIT3', 'DPCD', '0']
# single_pair ['FOS', 'PITX2', '0']
# single_pair ['PTTG1', 'OCIAD2', '0']
# single_pair ['OTX2', 'TNNI3', '0']
# single_pair ['MCM3', 'VTN', '0']
# single_pair ['ZNF143', 'DKC1', '0']
# single_pair ['PTTG1', 'PMAIP1', '0']
# single_pair ['MCM3', 'SCHIP1', '0']
# single_pair ['DDIT3', 'OCIAD2', '0']
# single_pair ['NFYB', 'ASNS', '0']
# single_pair ['FOS', 'PRKCE', '1']
# single_pair ['CRABP2', 'MT2A', '0']
# single_pair ['OTX2', 'FANCB', '0']
# single_pair ['PITX2', 'ADM', '0']
# single_pair ['MCM3', 'PMAIP1', '0']
# single_pair ['DDIT3', 'CDC20', '0']
# single_pair ['ID3', 'GPC3', '0']
# single_pair ['MCM4', 'TGIF1', '0']
# single_pair ['FOS', 'PCCA', '1']
# single_pair ['MCM7', 'CCBL2', '0']
# single_pair ['OTX2', 'ACADVL', '0']
# single_pair ['ZNF143', 'PRMT5', '0']
# single_pair ['MCM3', 'PHF5A', '0']
# single_pair ['PITX2', 'PLK1', '0']
# single_pair ['TGIF1', 'CCBL2', '0']
# single_pair ['OTX2', 'ACTC1', '0']
# single_pair ['MCM4', 'LGALS1', '0']
# single_pair ['DDIT3', 'CCNH', '0']
# single_pair ['OTX2', 'UBE2T', '0']
# single_pair ['MCM7', 'NIP7', '0']
# single_pair ['NFYB', 'PLCD1', '0']
# single_pair ['PTTG1', 'ATG5', '0']
# single_pair ['ZNF143', 'OTX2', '0']
# single_pair ['ID2', 'CCBL2', '0']
# single_pair ['MCM4', 'CCNH', '0']
# single_pair ['KNTC1', 'KLF6', '0']
# single_pair ['PITX2', 'NEK2', '0']
# single_pair ['DDIT3', 'MT2A', '0']
# single_pair ['DDIT3', 'CCL2', '0']
# single_pair ['TGIF1', 'ZWILCH', '0']
# single_pair ['CRABP2', 'CYP3A5', '0']
# single_pair ['CRABP2', 'NIF3L1', '0']
# single_pair ['ID3', 'OTX2', '0']
# single_pair ['PTTG1', 'MRPS27', '0']
# single_pair ['ID3', 'SCHIP1', '0']
# single_pair ['PTTG1', 'CCS', '0']
# single_pair ['ID3', 'TGIF1', '0']
# single_pair ['PITX2', 'MCM4', '0']
# single_pair ['KNTC1', 'ID3', '0']
# single_pair ['PITX2', 'DPCD', '0']
# single_pair ['KLF6', 'TGIF1', '0']
# single_pair ['MCM3', 'NIF3L1', '0']
# single_pair ['PITX2', 'TF', '0']
# single_pair ['MCM4', 'TNNI3', '0']
# single_pair ['FOS', 'NIP7', '0']
# single_pair ['TGIF1', 'ACTC1', '1']
# single_pair ['CRABP2', 'ICA1', '0']
# single_pair ['FOS', 'PTTG1', '0']
# single_pair ['TGIF1', 'NIF3L1', '0']
# single_pair ['OTX2', 'IQGAP2', '0']
# single_pair ['PTTG1', 'ACTL6A', '0']
# single_pair ['KLF6', 'CYP3A5', '0']
# single_pair ['PTTG1', 'CAPN12', '0']
# single_pair ['MCM3', 'LGALS1', '0']
# single_pair ['ID2', 'ACTC1', '0']
# single_pair ['CRABP2', 'MCM4', '0']
# single_pair ['RUVBL1', 'APEH', '0']
# single_pair ['ZNF143', 'SCHIP1', '0']
# single_pair ['FOS', 'PLK1', '0']
# single_pair ['PTTG1', 'SMYD3', '0']
# single_pair ['CRABP2', 'WARS', '0']
# single_pair ['ID3', 'MCM3', '0']
# single_pair ['FOS', 'TPD52L1', '1']
# single_pair ['OTX2', 'TM2D2', '0']
# All genes:24
# TFs:9
# len(single_pair) 3
# Generating matrix of gene pair 0 0
# Generating matrix of gene pair 0 1
# Generating matrix of gene pair 0 2
# Generating matrix of gene pair 0 3
# Generating matrix of gene pair 0 4
# Generating matrix of gene pair 0 5
# Generating matrix of gene pair 0 6
# Generating matrix of gene pair 0 7
# Generating matrix of gene pair 0 8
# Generating matrix of gene pair 0 9
# Generating matrix of gene pair 0 10
# Generating matrix of gene pair 0 11
# Generating matrix of gene pair 0 12
# Generating matrix of gene pair 0 13
# Generating matrix of gene pair 0 14
# Generating matrix of gene pair 0 15
# Generating matrix of gene pair 0 16
# Generating matrix of gene pair 0 17
# Generating matrix of gene pair 0 18
# Generating matrix of gene pair 0 19
# Generating matrix of gene pair 0 20
# Generating matrix of gene pair 0 21
# Generating matrix of gene pair 0 22
# Generating matrix of gene pair 0 23
# Generating matrix of gene pair 1 0
# Generating matrix of gene pair 1 1
# Generating matrix of gene pair 1 2
# Generating matrix of gene pair 1 3
# Generating matrix of gene pair 1 4
# Generating matrix of gene pair 1 5
# Generating matrix of gene pair 1 6
# Generating matrix of gene pair 1 7
# Generating matrix of gene pair 1 8
# Generating matrix of gene pair 1 9
# Generating matrix of gene pair 1 10
# Generating matrix of gene pair 1 11
# Generating matrix of gene pair 1 12
# Generating matrix of gene pair 1 13
# Generating matrix of gene pair 1 14
# Generating matrix of gene pair 1 15
# Generating matrix of gene pair 1 16
# Generating matrix of gene pair 1 17
# Generating matrix of gene pair 1 18
# Generating matrix of gene pair 1 19
# Generating matrix of gene pair 1 20
# Generating matrix of gene pair 1 21
# Generating matrix of gene pair 1 22
# Generating matrix of gene pair 1 23
# Generating matrix of gene pair 2 0
# Generating matrix of gene pair 2 1
# Generating matrix of gene pair 2 2
# Generating matrix of gene pair 2 3
# Generating matrix of gene pair 2 4
# Generating matrix of gene pair 2 5
# Generating matrix of gene pair 2 6
# Generating matrix of gene pair 2 7
# Generating matrix of gene pair 2 8
# Generating matrix of gene pair 2 9
# Generating matrix of gene pair 2 10
# Generating matrix of gene pair 2 11
# Generating matrix of gene pair 2 12
# Generating matrix of gene pair 2 13
# Generating matrix of gene pair 2 14
# Generating matrix of gene pair 2 15
# Generating matrix of gene pair 2 16
# Generating matrix of gene pair 2 17
# Generating matrix of gene pair 2 18
# Generating matrix of gene pair 2 19
# Generating matrix of gene pair 2 20
# Generating matrix of gene pair 2 21
# Generating matrix of gene pair 2 22
# Generating matrix of gene pair 2 23
# Generating matrix of gene pair 3 0
# Generating matrix of gene pair 3 1
# Generating matrix of gene pair 3 2
# Generating matrix of gene pair 3 3
# Generating matrix of gene pair 3 4
# Generating matrix of gene pair 3 5
# Generating matrix of gene pair 3 6
# Generating matrix of gene pair 3 7
# Generating matrix of gene pair 3 8
# Generating matrix of gene pair 3 9
# Generating matrix of gene pair 3 10
# Generating matrix of gene pair 3 11
# Generating matrix of gene pair 3 12
# Generating matrix of gene pair 3 13
# Generating matrix of gene pair 3 14
# Generating matrix of gene pair 3 15
# Generating matrix of gene pair 3 16
# Generating matrix of gene pair 3 17
# Generating matrix of gene pair 3 18
# Generating matrix of gene pair 3 19
# Generating matrix of gene pair 3 20
# Generating matrix of gene pair 3 21
# Generating matrix of gene pair 3 22
# Generating matrix of gene pair 3 23
# Generating matrix of gene pair 4 0
# Generating matrix of gene pair 4 1
# Generating matrix of gene pair 4 2
# Generating matrix of gene pair 4 3
# Generating matrix of gene pair 4 4
# Generating matrix of gene pair 4 5
# Generating matrix of gene pair 4 6
# Generating matrix of gene pair 4 7
# Generating matrix of gene pair 4 8
# Generating matrix of gene pair 4 9
# Generating matrix of gene pair 4 10
# Generating matrix of gene pair 4 11
# Generating matrix of gene pair 4 12
# Generating matrix of gene pair 4 13
# Generating matrix of gene pair 4 14
# Generating matrix of gene pair 4 15
# Generating matrix of gene pair 4 16
# Generating matrix of gene pair 4 17
# Generating matrix of gene pair 4 18
# Generating matrix of gene pair 4 19
# Generating matrix of gene pair 4 20
# Generating matrix of gene pair 4 21
# Generating matrix of gene pair 4 22
# Generating matrix of gene pair 4 23
# Generating matrix of gene pair 5 0
# Generating matrix of gene pair 5 1
# Generating matrix of gene pair 5 2
# Generating matrix of gene pair 5 3
# Generating matrix of gene pair 5 4
# Generating matrix of gene pair 5 5
# Generating matrix of gene pair 5 6
# Generating matrix of gene pair 5 7
# Generating matrix of gene pair 5 8
# Generating matrix of gene pair 5 9
# Generating matrix of gene pair 5 10
# Generating matrix of gene pair 5 11
# Generating matrix of gene pair 5 12
# Generating matrix of gene pair 5 13
# Generating matrix of gene pair 5 14
# Generating matrix of gene pair 5 15
# Generating matrix of gene pair 5 16
# Generating matrix of gene pair 5 17
# Generating matrix of gene pair 5 18
# Generating matrix of gene pair 5 19
# Generating matrix of gene pair 5 20
# Generating matrix of gene pair 5 21
# Generating matrix of gene pair 5 22
# Generating matrix of gene pair 5 23
# Generating matrix of gene pair 6 0
# Generating matrix of gene pair 6 1
# Generating matrix of gene pair 6 2
# Generating matrix of gene pair 6 3
# Generating matrix of gene pair 6 4
# Generating matrix of gene pair 6 5
# Generating matrix of gene pair 6 6
# Generating matrix of gene pair 6 7
# Generating matrix of gene pair 6 8
# Generating matrix of gene pair 6 9
# Generating matrix of gene pair 6 10
# Generating matrix of gene pair 6 11
# Generating matrix of gene pair 6 12
# Generating matrix of gene pair 6 13
# Generating matrix of gene pair 6 14
# Generating matrix of gene pair 6 15
# Generating matrix of gene pair 6 16
# Generating matrix of gene pair 6 17
# Generating matrix of gene pair 6 18
# Generating matrix of gene pair 6 19
# Generating matrix of gene pair 6 20
# Generating matrix of gene pair 6 21
# Generating matrix of gene pair 6 22
# Generating matrix of gene pair 6 23
# Generating matrix of gene pair 7 0
# Generating matrix of gene pair 7 1
# Generating matrix of gene pair 7 2
# Generating matrix of gene pair 7 3
# Generating matrix of gene pair 7 4
# Generating matrix of gene pair 7 5
# Generating matrix of gene pair 7 6
# Generating matrix of gene pair 7 7
# Generating matrix of gene pair 7 8
# Generating matrix of gene pair 7 9
# Generating matrix of gene pair 7 10
# Generating matrix of gene pair 7 11
# Generating matrix of gene pair 7 12
# Generating matrix of gene pair 7 13
# Generating matrix of gene pair 7 14
# Generating matrix of gene pair 7 15
# Generating matrix of gene pair 7 16
# Generating matrix of gene pair 7 17
# Generating matrix of gene pair 7 18
# Generating matrix of gene pair 7 19
# Generating matrix of gene pair 7 20
# Generating matrix of gene pair 7 21
# Generating matrix of gene pair 7 22
# Generating matrix of gene pair 7 23
# Generating matrix of gene pair 8 0
# Generating matrix of gene pair 8 1
# Generating matrix of gene pair 8 2
# Generating matrix of gene pair 8 3
# Generating matrix of gene pair 8 4
# Generating matrix of gene pair 8 5
# Generating matrix of gene pair 8 6
# Generating matrix of gene pair 8 7
# Generating matrix of gene pair 8 8
# Generating matrix of gene pair 8 9
# Generating matrix of gene pair 8 10
# Generating matrix of gene pair 8 11
# Generating matrix of gene pair 8 12
# Generating matrix of gene pair 8 13
# Generating matrix of gene pair 8 14
# Generating matrix of gene pair 8 15
# Generating matrix of gene pair 8 16
# Generating matrix of gene pair 8 17
# Generating matrix of gene pair 8 18
# Generating matrix of gene pair 8 19
# Generating matrix of gene pair 8 20
# Generating matrix of gene pair 8 21
# Generating matrix of gene pair 8 22
# Generating matrix of gene pair 8 23
# PCC matrix generation finish.
# Positive edges:16
# Negative edges:144
# Density=0.1

# %%
##the data path of known data
data_path = 'data/input/known/'

##the data path of unknown data
unknown_data_path = 'data/input/unknow/'
num_threads = 16
##training model and then predicting unknown network
prediction = STGRNSForGRNSRconstruction(32,500,data_path,unknown_data_path,num_threads)
# Out:
# [Train | 001/500] Loss = 0.37048
# [Train | 002/500] Loss = 0.31157
# [Train | 003/500] Loss = 0.27464
# [Train | 004/500] Loss = 0.24280
# [Train | 005/500] Loss = 0.22570
# [Train | 006/500] Loss = 0.21002
# [Train | 007/500] Loss = 0.19185
# [Train | 008/500] Loss = 0.17118
# [Train | 009/500] Loss = 0.14562
# [Train | 465/500] Loss = 0.00067
# [Train | 466/500] Loss = 0.00361
# [Train | 467/500] Loss = 0.00244
# [Train | 468/500] Loss = 0.00018
# [Train | 469/500] Loss = 0.00026
# [Train | 470/500] Loss = 0.00040
# [Train | 471/500] Loss = 0.00027
# [Train | 472/500] Loss = 0.00032
# [Train | 473/500] Loss = 0.00010
# [Train | 474/500] Loss = 0.01569
# [Train | 475/500] Loss = 0.00031
# [Train | 476/500] Loss = 0.00018
# [Train | 477/500] Loss = 0.00023
# [Train | 478/500] Loss = 0.00025
# [Train | 479/500] Loss = 0.00049
# [Train | 480/500] Loss = 0.00009
# [Train | 481/500] Loss = 0.00012
# [Train | 482/500] Loss = 0.00012
# [Train | 483/500] Loss = 0.00021
# [Train | 484/500] Loss = 0.00026
# [Train | 485/500] Loss = 0.00019
# [Train | 486/500] Loss = 0.00015
# [Train | 487/500] Loss = 0.00045
# [Train | 488/500] Loss = 0.00022
# [Train | 489/500] Loss = 0.00024
# [Train | 490/500] Loss = 0.00006
# [Train | 491/500] Loss = 0.00015
# [Train | 492/500] Loss = 0.00012
# [Train | 493/500] Loss = 0.00013
# [Train | 494/500] Loss = 0.00020
# [Train | 495/500] Loss = 0.00003
# [Train | 496/500] Loss = 0.00022
# [Train | 497/500] Loss = 0.00009
# [Train | 498/500] Loss = 0.00019
# [Train | 499/500] Loss = 0.00008
# [Train | 500/500] Loss = 0.00022
# ROC AUC: 0.6493
# PR AUC: 0.1640
# AUPR Ratio (AUPR / pos_rate): 1.6397
# Early Precision @ Recall=0.1: 0.1000
# Early Precision Ratio: 1.0000
# Accuracy: 0.8438, Balanced Acc: 0.5521, F1 Score: 0.1935

# %%
# After obtaining y_true (array of 0/1) and y_scores (probabilities 0–1):
from sklearn import metrics
import numpy as np
import os

log_dir = "log/"

# Load the saved prediction arrays
y_true = np.load(os.path.join(log_dir, 'y_test.npy'))
y_scores = np.load(os.path.join(log_dir, 'y_scores.npy'))
y_pred = np.load(os.path.join(log_dir, 'y_pred.npy'))

# ROC AUC
fpr, tpr, _ = metrics.roc_curve(y_true, y_scores, pos_label=1)
roc_auc = metrics.auc(fpr, tpr)

# Precision-Recall AUC
precision, recall, _ = metrics.precision_recall_curve(y_true, y_scores)
pr_auc = metrics.auc(recall, precision)

# Baseline (random) AUPR
pos_rate = np.mean(y_true)
pr_auc_ratio = pr_auc / pos_rate

# Early Precision at Recall >= 0.1
recall_target = 0.1
idx = np.argmax(recall >= recall_target)
early_precision = precision[idx]
early_precision_ratio = early_precision / pos_rate

print(f"ROC AUC: {roc_auc:.4f}")
print(f"PR AUC: {pr_auc:.4f}")
print(f"AUPR Ratio: {pr_auc_ratio:.4f}")
print(f"Early Precision (Recall ≥ {recall_target}): {early_precision:.4f}")
print(f"Early Precision Ratio: {early_precision_ratio:.4f}")
# Out:
# ROC AUC: 0.6493
# PR AUC: 0.1640
# AUPR Ratio: 1.6397
# Early Precision (Recall ≥ 0.1): 0.1000
# Early Precision Ratio: 1.0000
